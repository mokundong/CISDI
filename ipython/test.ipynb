# %%
import pandas as pd
import numpy as np
import os

# %%
pd.read_csv('df.csv')
# Out:
#        Unnamed: 0  X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  X11  X12  X13  \
# 0               1   2   4   1   3   5   4   4   2   3    5    5    5    3
# 1               2   3   2   4   3   2   5   3   3   3    4    2    3    1
# 2               3   5   1   5   5   2   4   4   3   1    1    3    2    3
# 3               4   1   2   1   1   3   5   2   2   1    3    5    5    4
# 4               5   3   1   1   3   2   3   1   4   1    5    4    3    3
# 5               6   4   2   2   2   3   1   1   1   4    4    3    2    4
# 6               7   2   1   2   5   2   1   5   2   4    4    4    4    1
# 7               8   5   3   2   1   5   1   5   3   4    4    5    1    5
# 8               9   5   5   2   3   2   4   2   5   1    5    4    2    1
# 9              10   4   4   2   1   4   5   4   1   5    4    1    1    1
# 10             11   1   3   2   3   4   4   4   5   4    1    4    2    3
# 11             12   2   3   2   1   3   2   2   3   3    2    4    3    3
# ...

# %%
a=pd.read_csv('res.csv')

# %%
len(a)
# Out:
# 59575

# %%
a
# Out:
#        Unnamed: 0                              rules  support  confidence  \
# 0               1              {X10=5} => {target=A}  0.14764    0.748454
# 1               2               {X9=1} => {target=A}  0.14696    0.744026
# 2               3               {X7=3} => {target=A}  0.14749    0.746596
# 3               4               {X8=5} => {target=A}  0.14715    0.744046
# 4               5              {X11=2} => {target=A}  0.14835    0.749432
# 5               6               {X2=4} => {target=A}  0.14894    0.751349
# 6               7               {X7=4} => {target=A}  0.14797    0.746456
# 7               8               {X3=5} => {target=A}  0.14818    0.746913
# 8               9               {X5=2} => {target=A}  0.14819    0.746700
# 9              10              {X12=2} => {target=A}  0.14799    0.745391
# 10             11              {X10=3} => {target=A}  0.14923    0.750654
# 11             12               {X1=5} => {target=A}  0.14770    0.742808
# ...
